# %%
import os
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#main_df = pd.read_csv('filtered.csv')
cast_df = pd.read_csv('name.basics.tsv', sep='\t')

# %%
cast_df.dropna(inplace=True)

# %%
cast_df = cast_df[cast_df.primaryProfession.str.contains('actor')]

# %%
main_df = pd.read_csv('filtered.csv')
main_df.drop_duplicates('tconst', keep='last', inplace=True)

# %%
#main_df['actors'] = ''
for i in tqdm(main_df.tconst.index):
    if str(main_df.loc[i, 'actors']) == '' or str(main_df.loc[i, 'actors']).lower()=='nan':
        d = cast_df[cast_df.knownForTitles.str.contains(main_df.loc[i, 'tconst'])]
        if d.shape[0]>0:
            main_df.loc[i, 'actors'] = ''
            main_df.loc[i, 'actors'] += ','.join(d.primaryName.tolist())

# %%
main_df
# Out:
#           tconst  ordering              title region language        types  \
# 0      tt0044008        20            Scrooge     CA       en  imdbDisplay
# 1      tt0046949         3       The Egyptian     CA       en  imdbDisplay
# 2      tt0054152         9  Our Man in Havana     CA       en  imdbDisplay
# 3      tt0054412        15     Tunes of Glory     CA       en  imdbDisplay
# 4      tt0057261        24  Lord of the Flies     CA       en  imdbDisplay
# ...          ...       ...                ...    ...      ...          ...
# 15373  tt7019842         7                 96     IN       en  imdbDisplay
# 15374  tt7645780         5  The Wedding Guest     IN       en  imdbDisplay
# 15375  tt7919680         7            Karwaan     IN       en  imdbDisplay
# 15376  tt8563452         1             Crypto     CA       en  imdbDisplay
# 15377  tt8972256         6              Greed     IN       en  imdbDisplay
#
# ...

# %%
main_df.to_csv('filtered.csv', index=False)
